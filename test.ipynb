# %%
import pandas as pd
tweets_old = pd.read_csv('data/final/training_data_labelled.csv')
tweets_new = pd.read_csv('data/final/training_data_labelled_new.csv')

# %%
tweets_old.shape, tweets_new.shape
# Out:
# ((3704, 10), (3501, 11))

# %%
tweets_old.AR.value_counts().sort_index()
# Out:
# AR
# 1    1377
# 2     855
# 3    1471
# 4       1
# Name: count, dtype: int64

# %%
tweets_new.AR.value_counts().sort_index()
# Out:
# AR
# 1    1340
# 2     773
# 3    1387
# 4       1
# Name: count, dtype: int64
